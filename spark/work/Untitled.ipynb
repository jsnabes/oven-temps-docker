# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /Users/snabes/anaconda3/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/snabes/anaconda3/lib/python3.11/site-packages (from pyspark) (0.10.9.7)

# %%
import pyspark
from pyspark.sql import SparkSession

BOOTSTRAP_SERVERS = "localhost:29092"
TOPIC = "oven"

# %%
def main():
    # spark = SparkSession.builder.master("local[1]") \
    #     .appName('OvenTempReader') \
    #     .getOrCreate()

    spark = SparkSession.builder.master("local[1]") \
        .appName('OvenTempReader') \
        .config('spark.jars.packages', 'org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.1') \
        .getOrCreate()

    df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", BOOTSTRAP_SERVERS) \
        .option("session.timeout.ms", "4000") \
        .option("subscribe", TOPIC) \
        .load()

    query = df.selectExpr("CAST(value AS STRING)") \
        .writeStream \
        .outputMode("append") \
        .format("console") \
        .start()

    query.awaitTermination()

# %%
#main()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
spark = SparkSession.builder.master("local[1]") \
    .appName('OvenTempReader') \
    .config('spark.jars.packages', 'org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.1') \
    .getOrCreate()

df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", BOOTSTRAP_SERVERS) \
    .option("session.timeout.ms", "4000") \
    .option("subscribe", TOPIC) \
    .option("startingOffsets", "latest") \
    .load()

base_df = df.selectExpr("CAST(value as STRING)", "timestamp") \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .start() \
    .awaitTermination()
#base_df.printSchema()
# Out:
# 23/12/01 14:08:53 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/sy/xb_6z8y117bd4msf48bkbfwm0000gn/T/temporary-b0c33135-c60a-4388-b93d-13c2f433d4ba. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 23/12/01 14:08:53 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 172
# -------------------------------------------
# -------------------------------------------
# Batch: 79
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  390|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  390|2023-12-01 14:08:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  390|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  452|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 80
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  452|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 173
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  452|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 81
# -------------------------------------------
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  294|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 174
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  294|2023-12-01 14:08:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  294|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 82
# -------------------------------------------
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  347|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 175
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  347|2023-12-01 14:08:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  347|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-----+---------+
# |value|timestamp|
# +-----+---------+
# +-----+---------+
#
# -------------------------------------------
# Batch: 83
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  495|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  495|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 176
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  495|2023-12-01 14:08:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  495|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# -------------------------------------------
# Batch: 84
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  400|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 177
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  400|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 51
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  400|2023-12-01 14:08:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  400|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 85
# -------------------------------------------
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  261|2023-12-01 14:08:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  261|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 178
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  261|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 52
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  261|2023-12-01 14:08:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 53
# -------------------------------------------
# -------------------------------------------
# Batch: 179
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  255|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 86
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  255|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  255|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  255|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# -------------------------------------------
# Batch: 54
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  318|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 180
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  318|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  318|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 87
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  318|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 55
# -------------------------------------------
# -------------------------------------------
# Batch: 88
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  407|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 181
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  407|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  407|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  407|2023-12-01 14:09:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 56
# -------------------------------------------
# -------------------------------------------
# Batch: 89
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  328|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  328|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  328|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 182
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  328|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# -------------------------------------------
# Batch: 57
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 90
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 183
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 58
# -------------------------------------------
# -------------------------------------------
# Batch: 91
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  468|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  468|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  468|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 184
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  468|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 59
# -------------------------------------------
# -------------------------------------------
# Batch: 92
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  404|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 185
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  404|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  404|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  404|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 93
# -------------------------------------------
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  369|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 60
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  369|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 186
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  369|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  369|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 61
# -------------------------------------------
# -------------------------------------------
# Batch: 94
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  442|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  442|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 187
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  442|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  442|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 95
# -------------------------------------------
# -------------------------------------------
# Batch: 62
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  336|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 188
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  336|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  336|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  336|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# -------------------------------------------
# Batch: 189
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 96
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 63
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  296|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 64
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  344|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  344|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 97
# -------------------------------------------
# -------------------------------------------
# Batch: 190
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  344|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  344|2023-12-01 14:09:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 191
# -------------------------------------------
# -------------------------------------------
# Batch: 98
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  356|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  356|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  356|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 65
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  356|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 99
# -------------------------------------------
# -------------------------------------------
# Batch: 66
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  267|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 192
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  267|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  267|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  267|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  461|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 193
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  461|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 100
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  461|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 67
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  461|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  412|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 194
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  412|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 101
# -------------------------------------------
# -------------------------------------------
# Batch: 68
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  412|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  412|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 195
# -------------------------------------------
# -------------------------------------------
# Batch: 69
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 102
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 103
# -------------------------------------------
# -------------------------------------------
# Batch: 196
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  448|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  448|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 70
# -------------------------------------------
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  448|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  448|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 104
# -------------------------------------------
# -------------------------------------------
# Batch: 197
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  389|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  389|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 71
# -------------------------------------------
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  389|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  389|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 105
# -------------------------------------------
# -------------------------------------------
# Batch: 198
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  311|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  311|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 72
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  311|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  311|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 199
# -------------------------------------------
# -------------------------------------------
# Batch: 106
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 73
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:09:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 74
# -------------------------------------------
# -------------------------------------------
# Batch: 107
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  380|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  380|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 200
# -------------------------------------------
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  380|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  380|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# -------------------------------------------
# Batch: 201
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 108
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 75
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 202
# -------------------------------------------
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  263|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 76
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  263|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 109
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  263|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  263|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 110
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  284|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 203
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  284|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  284|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 77
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  284|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 204
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 111
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 78
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 112
# -------------------------------------------
# -------------------------------------------
# Batch: 79
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 205
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 206
# -------------------------------------------
# -------------------------------------------
# Batch: 113
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  452|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 80
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  452|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  452|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  452|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# -------------------------------------------
# Batch: 81
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 114
# -------------------------------------------
# -------------------------------------------
# Batch: 207
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 208
# -------------------------------------------
# -------------------------------------------
# Batch: 115
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 82
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  482|2023-12-01 14:09:...|
# +-----+--------------------+
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/Users/snabes/anaconda3/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/snabes/anaconda3/lib/python3.11/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/snabes/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 20
#       1 spark = SparkSession.builder.master("local[1]") \
#       2     .appName('OvenTempReader') \
#       3     .config('spark.jars.packages', 'org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.1') \
#       4     .getOrCreate()
#       6 df = spark \
#       7     .readStream \
#       8     .format("kafka") \
#    (...)
#      12     .option("startingOffsets", "latest") \
#      13     .load()
#      15 base_df = df.selectExpr("CAST(value as STRING)", "timestamp") \
#      16     .writeStream \
#      17     .outputMode("append") \
#      18     .format("console") \
#      19     .start() \
# ---> 20     .awaitTermination()
#      21 #base_df.printSchema()
#      22 base_df.select('value').show()
#
# File ~/anaconda3/lib/python3.11/site-packages/pyspark/sql/streaming/query.py:221, in StreamingQuery.awaitTermination(self, timeout)
#     219     return self._jsq.awaitTermination(int(timeout * 1000))
#     220 else:
# --> 221     return self._jsq.awaitTermination()
#
# File ~/anaconda3/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/anaconda3/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/anaconda3/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
base_df.select('value').show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 base_df.select('value').show()
#
# AttributeError: 'StreamingQuery' object has no attribute 'select'
# -------------------------------------------
# Batch: 126
# -------------------------------------------
# -------------------------------------------
# Batch: 252
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  345|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  345|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 77
# -------------------------------------------
# -------------------------------------------
# Batch: 159
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  345|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  345|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 160
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  449|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 253
# -------------------------------------------
# -------------------------------------------
# Batch: 78
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  449|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  449|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 127
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  449|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 128
# -------------------------------------------
# -------------------------------------------
# Batch: 254
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  430|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  430|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 161
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  430|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 79
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  430|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 129
# -------------------------------------------
# -------------------------------------------
# Batch: 255
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  268|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  268|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 162
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  268|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 80
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  268|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 81
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  390|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 130
# -------------------------------------------
# -------------------------------------------
# Batch: 163
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  390|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  390|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 256
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  390|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 131
# -------------------------------------------
# -------------------------------------------
# Batch: 257
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  498|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  498|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 164
# -------------------------------------------
# -------------------------------------------
# Batch: 82
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  498|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  498|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 258
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  416|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 132
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  416|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 165
# -------------------------------------------
# -------------------------------------------
# Batch: 83
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  416|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  416|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 259
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  334|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 166
# -------------------------------------------
# -------------------------------------------
# Batch: 84
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  334|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 133
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  334|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  334|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 134
# -------------------------------------------
# -------------------------------------------
# Batch: 167
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 260
# -------------------------------------------
# -------------------------------------------
# Batch: 85
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 261
# -------------------------------------------
# -------------------------------------------
# Batch: 135
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  457|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  457|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 86
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  457|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 168
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  457|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 262
# -------------------------------------------
# -------------------------------------------
# Batch: 136
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  312|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  312|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 87
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  312|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 169
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  312|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 88
# -------------------------------------------
# -------------------------------------------
# Batch: 263
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  287|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  287|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 170
# -------------------------------------------
# -------------------------------------------
# Batch: 137
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  287|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  287|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 171
# -------------------------------------------
# -------------------------------------------
# Batch: 138
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 89
# -------------------------------------------
# -------------------------------------------
# Batch: 264
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 90
# -------------------------------------------
# -------------------------------------------
# Batch: 265
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 172
# -------------------------------------------
# -------------------------------------------
# Batch: 139
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 91
# -------------------------------------------
# -------------------------------------------
# Batch: 266
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  477|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 140
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  477|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 173
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  477|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  477|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 141
# -------------------------------------------
# -------------------------------------------
# Batch: 92
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  409|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 267
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  409|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 174
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  409|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  409|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 93
# -------------------------------------------
# -------------------------------------------
# Batch: 142
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  370|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  370|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 268
# -------------------------------------------
# -------------------------------------------
# Batch: 175
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  370|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  370|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 94
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  441|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 269
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  441|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 176
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  441|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 143
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  441|2023-12-01 14:10:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 95
# -------------------------------------------
# -------------------------------------------
# Batch: 177
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 270
# -------------------------------------------
# -------------------------------------------
# Batch: 144
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  333|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 271
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  392|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 145
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  392|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 178
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  392|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 96
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  392|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 146
# -------------------------------------------
# -------------------------------------------
# Batch: 272
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 97
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 179
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  258|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 180
# -------------------------------------------
# -------------------------------------------
# Batch: 98
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  481|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 147
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  481|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 273
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  481|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  481|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 148
# -------------------------------------------
# -------------------------------------------
# Batch: 99
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  327|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  327|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 181
# -------------------------------------------
# -------------------------------------------
# Batch: 274
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  327|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  327|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 182
# -------------------------------------------
# -------------------------------------------
# Batch: 149
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 100
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 275
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 183
# -------------------------------------------
# -------------------------------------------
# Batch: 101
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  422|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 276
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  422|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 150
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  422|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  422|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 151
# -------------------------------------------
# -------------------------------------------
# Batch: 102
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 277
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 184
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 103
# -------------------------------------------
# -------------------------------------------
# Batch: 152
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  359|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  359|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 185
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  359|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 278
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  359|2023-12-01 14:10:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 104
# -------------------------------------------
# -------------------------------------------
# Batch: 153
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  490|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  490|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 186
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  490|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 279
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  490|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 187
# -------------------------------------------
# -------------------------------------------
# Batch: 280
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 154
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 105
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  329|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 106
# -------------------------------------------
# -------------------------------------------
# Batch: 281
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 188
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 155
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  340|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 107
# -------------------------------------------
# -------------------------------------------
# Batch: 156
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 189
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 282
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 157
# -------------------------------------------
# -------------------------------------------
# Batch: 283
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 108
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 190
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 158
# -------------------------------------------
# -------------------------------------------
# Batch: 109
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 191
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 284
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  265|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 192
# -------------------------------------------
# -------------------------------------------
# Batch: 159
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  445|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 285
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  445|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  445|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 110
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  445|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 111
# -------------------------------------------
# -------------------------------------------
# Batch: 160
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  371|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  371|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 193
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  371|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 286
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  371|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 194
# -------------------------------------------
# -------------------------------------------
# Batch: 161
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  396|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 287
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  396|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  396|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 112
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  396|2023-12-01 14:10:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 195
# -------------------------------------------
# -------------------------------------------
# Batch: 162
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  476|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  476|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 288
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  476|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 113
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  476|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 196
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 114
# -------------------------------------------
# -------------------------------------------
# Batch: 163
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 289
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  488|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 290
# -------------------------------------------
# -------------------------------------------
# Batch: 164
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 115
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 197
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 198
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  335|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 291
# -------------------------------------------
# -------------------------------------------
# Batch: 116
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  335|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 165
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  335|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  335|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 117
# -------------------------------------------
# -------------------------------------------
# Batch: 166
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  283|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  283|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 292
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  283|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 199
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  283|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 167
# -------------------------------------------
# -------------------------------------------
# Batch: 118
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 200
# -------------------------------------------
# -------------------------------------------
# Batch: 293
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 168
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 119
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 294
# -------------------------------------------
# -------------------------------------------
# Batch: 201
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  372|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 202
# -------------------------------------------
# -------------------------------------------
# Batch: 120
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  496|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  496|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 295
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  496|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 169
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  496|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 203
# -------------------------------------------
# -------------------------------------------
# Batch: 170
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 121
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 296
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  264|2023-12-01 14:10:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 297
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  274|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 204
# -------------------------------------------
# -------------------------------------------
# Batch: 122
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  274|2023-12-01 14:10:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  274|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 171
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  274|2023-12-01 14:10:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 123
# -------------------------------------------
# -------------------------------------------
# Batch: 172
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 298
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 205
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:11:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  479|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 299
# -------------------------------------------
# -------------------------------------------
# Batch: 173
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  387|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 124
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  387|2023-12-01 14:11:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  387|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 206
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  387|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 300
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  334|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 125
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  334|2023-12-01 14:11:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 207
# -------------------------------------------
# -------------------------------------------
# Batch: 174
# -------------------------------------------
# ...
# |  273|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 345
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  273|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 428
# -------------------------------------------
# -------------------------------------------
# Batch: 521
# -------------------------------------------
# -------------------------------------------
# Batch: 395
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  499|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  499|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  499|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 346
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  499|2023-12-01 14:14:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 429
# -------------------------------------------
# -------------------------------------------
# Batch: 522
# -------------------------------------------
# -------------------------------------------
# Batch: 347
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 396
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  298|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 348
# -------------------------------------------
# -------------------------------------------
# Batch: 397
# -------------------------------------------
# -------------------------------------------
# Batch: 430
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 523
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  453|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 524
# -------------------------------------------
# -------------------------------------------
# Batch: 349
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 398
# -------------------------------------------
# -------------------------------------------
# Batch: 431
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  437|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 350
# -------------------------------------------
# -------------------------------------------
# Batch: 399
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  393|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  393|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 525
# -------------------------------------------
# -------------------------------------------
# Batch: 432
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  393|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  393|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 400
# -------------------------------------------
# -------------------------------------------
# Batch: 433
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  460|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  460|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 351
# -------------------------------------------
# -------------------------------------------
# Batch: 526
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  460|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  460|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 352
# -------------------------------------------
# -------------------------------------------
# Batch: 401
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  382|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  382|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 527
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  382|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 434
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  382|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 435
# -------------------------------------------
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  459|2023-12-01 14:14:...|
# +-----+--------------------+
#
# Batch: 528
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  459|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 353
# -------------------------------------------
# -------------------------------------------
# Batch: 402
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  459|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  459|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 403
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  478|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 529
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  478|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 436
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  478|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 354
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  478|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 437
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 404
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 355
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 530
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  354|2023-12-01 14:14:...|
# +-----+--------------------+
# -------------------------------------------
# Batch: 405
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  365|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 356
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  365|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 531
# -------------------------------------------
# -------------------------------------------
# Batch: 438
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  365|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  365|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 532
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  252|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 357
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  252|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 439
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  252|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 406
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  252|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 358
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  432|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 407
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  432|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 533
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  432|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 440
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  432|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 534
# -------------------------------------------
# -------------------------------------------
# Batch: 408
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  374|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  374|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 359
# -------------------------------------------
# -------------------------------------------
# Batch: 441
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  374|2023-12-01 14:14:...|
# +-----+--------------------+
#
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  374|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 535
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  497|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 360
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  497|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 442
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  497|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 409
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  497|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 361
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  288|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 443
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  288|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 536
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  288|2023-12-01 14:14:...|
# +-----+--------------------+
#
# -------------------------------------------
# Batch: 410
# -------------------------------------------
# +-----+--------------------+
# |value|           timestamp|
# +-----+--------------------+
# |  288|2023-12-01 14:14:...|
# +-----+--------------------+
